# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
ds = xr.open_dataset("/home/ubuntu/onav-cloud/Ocean-Data-Map-Project/giops_day_46N173W-56N-167W_20250618_NETCDF4.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 52, depth: 50, time: 1, longitude: 1707)
# Coordinates:
#   * latitude   (latitude) float32 46.2 46.4 46.6 46.8 ... 55.8 56.0 56.2 56.4
#   * depth      (depth) float32 0.494 1.541 2.646 ... 5.275e+03 5.728e+03
#   * time       (time) datetime64[ns] 2025-06-18
#   * longitude  (longitude) float32 -167.8 -167.6 -167.4 ... 173.0 173.2 173.4
# Data variables:
#     votemper   (time, depth, latitude, longitude) float32 ...
# Attributes:
#     Conventions:      CF-1.6
#     title:            Ice ocean analysis fields
#     institution:      The Canadian Centre for Meteorological and Environmenta...
#     source:           Global Ice Ocean Prediction System: version 3.4.0
#     product_version:  GIOPS_3.4.0
#     creation_date:    2025-Jun-18 02:17:54 UTC
#     contact:          production-info@ec.gc.ca

# %%
plt.figure(figsize=(20,5))
plt.imshow(np.flipud(ds.votemper.data[0,0,:,:]))

# %%
ds = xr.open_dataset("60N174W-72N-151W-20250618_NETCDF4.nc")
plt.figure(figsize=(20,5))
plt.imshow(np.flipud(ds.votemper.data[0,0,:,:]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/onav-cloud/tools/miniconda/3/amd64/envs/navigator/lib/python3.12/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/onav-cloud/tools/miniconda/3/amd64/envs/navigator/lib/python3.12/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/ubuntu/onav-cloud/Ocean-Data-Map-Project/giops_day_60N174W-72N-151W-20250618_NETCDF4.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '51f4c632-c0da-4354-85fc-53655d47dc60']
#
# ...

# %%
ds=xr.open_dataset("/home/ubuntu/onav-cloud/Ocean-Data-Map-Project/giops_day_61N177W-71N-153W_20250629_NETCDF4.nc")
plt.figure(figsize=(20,5))
plt.imshow(np.flipud(ds.votemper.data[0,0,:,:]))

# %%
giops = xr.open_dataset("/home/ubuntu/onav-cloud/Ocean-Data-Map-Project/giops_day_60N-52W-60N-26W_20250618_NETCDF4.nc")
giops
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 giops = xr.open_dataset("/home/ubuntu/onav-cloud/Ocean-Data-Map-Project/giops_day_60N-52W-60N-26W_20250618_NETCDF4.nc")
#       2 giops
#
# NameError: name 'xr' is not defined

# %%
plt.figure()
plt.imshow(np.flipud(giops.votemper[0,0,:,:]))

# %%
tests = xr.open_dataset("/home/ubuntu/onav-cloud/Ocean-Data-Map-Project/xarray subset example/CMC_giops_votemper_depth_all_latlon0.2x0.2_2025061800_Anal000.nc")
tests
# Out:
# <xarray.Dataset>
# Dimensions:             (longitude: 1800, latitude: 850, depth: 50, time: 1)
# Coordinates:
#   * longitude           (longitude) float32 0.0 0.2 0.4 ... 359.4 359.6 359.8
#   * latitude            (latitude) float32 -80.0 -79.8 -79.6 ... 89.4 89.6 89.8
#   * depth               (depth) float32 0.494 1.541 ... 5.275e+03 5.728e+03
#   * time                (time) datetime64[ns] 2025-06-18
# Data variables:
#     latitude_longitude  int32 ...
#     votemper            (time, depth, latitude, longitude) float32 ...
# Attributes:
#     Conventions:      CF-1.6
#     title:            Ice ocean analysis fields
#     institution:      The Canadian Centre for Meteorological and Environmenta...
#     source:           Global Ice Ocean Prediction System: version 3.4.0
#     product_version:  GIOPS_3.4.0
#     creation_date:    2025-Jun-18 02:17:54 UTC
#     contact:          production-info@ec.gc.ca

# %%
ds_new = tests.assign_coords({"longitude": (((tests.longitude + 180) % 360) - 180)})
ds_new = ds_new.sortby("longitude")

# %%
plt.figure(figsize=(20,5))
plt.imshow(np.flipud(ds_new.votemper.data[0,0,:,:]))

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
ds = xr.open_dataset("/home/ubuntu/onav-cloud/Ocean-Data-Map-Project/giops_day_46N-13W-58N3W_20250630_NETCDF4.nc")
plt.figure(figsize=(20,5))
plt.imshow(np.flipud(ds.votemper.data[0,0,:,:]))

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 86, latitude: 60, depth: 50, time: 1)
# Coordinates:
#   * longitude  (longitude) float32 346.6 346.8 347.0 347.2 ... 3.0 3.2 3.4 3.6
#   * latitude   (latitude) float32 46.8 47.0 47.2 47.4 ... 58.0 58.2 58.4 58.6
#   * depth      (depth) float32 0.494 1.541 2.646 ... 5.275e+03 5.728e+03
#   * time       (time) datetime64[ns] 2025-06-30
# Data variables:
#     votemper   (time, depth, latitude, longitude) float32 18.4 18.44 ... nan nan
# Attributes:
#     Conventions:      CF-1.6
#     title:            Instantaneous ice and ocean forecast fields
#     institution:      The Canadian Centre for Meteorological and Environmenta...
#     source:           Global Ice Ocean Prediction System: version 9.0.0
#     product_version:  GIOPS_9.0.0_F3
#     creation_date:    2025-Jun-20 04:41:44 UTC
#     contact:          production-info@ec.gc.ca
